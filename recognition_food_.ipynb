# %% [markdown]
# <a href="https://colab.research.google.com/github/vantung20146105/midterm/blob/main/recognition_food_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from keras.models import Sequential, Model 
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Normalization
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from os import listdir
from numpy import asarray, save
from keras.utils import load_img
from keras.utils import img_to_array
import numpy as np
from numpy import asarray
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping

# %%
# Kết nối với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Di chuyển tới thư mục 
# %cd /content/drive/MyDrive/Recognition_Food
# Out:
# /content/drive/MyDrive/Recognition_Food

# %%
# Khởi tạo dữ liệu cho quá trình training
train_data=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)
training = train_datagen.flow_from_directory('/content/drive/MyDrive/Recognition_Food/train',target_size = (150,150), batch_size = 32,class_mode='categorical')
validation=train_data.flow_from_directory('/content/drive/MyDrive/Recognition_Food/valid',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 2748 images belonging to 10 classes.
# Found 800 images belonging to 10 classes.

# %%
# Kiểm tra các thuộc tính của tập dữ liệu training
training.class_indices
# Out:
# {'Banh beo': 0,
#  'Banh chung': 1,
#  'Banh mi': 2,
#  'Banh pia': 3,
#  'Banh xeo': 4,
#  'Ca kho to': 5,
#  'Canh chua': 6,
#  'Com tam': 7,
#  'Pho': 8,
#  'Xoi xeo': 9}

# %%
# Kiểm tra các thuộc tính của tập dữ liệu validation
validation.class_indices
# Out:
# {'Banh beo': 0,
#  'Banh chung': 1,
#  'Banh mi': 2,
#  'Banh pia': 3,
#  'Banh xeo': 4,
#  'Ca kho to': 5,
#  'Canh chua': 6,
#  'Com tam': 7,
#  'Pho': 8,
#  'Xoi xeo': 9}

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()

model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))

model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))

model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))

model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 256)               10617088
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 10,906,666
# Trainable params: 10,906,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(
    optimizer = 'Adam',
    loss='categorical_crossentropy',
    metrics = 'accuracy'
)
model.summary()
# Tiến hành quá trình training
train = model.fit(training,epochs = 30,validation_data=validation,verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 256)               10617088
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 10,906,666
# Trainable params: 10,906,666
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 86/86 [==============================] - 1564s 18s/step - loss: 2.6526 - accuracy: 0.2613 - val_loss: 2.6476 - val_accuracy: 0.1513
# Epoch 2/30
# 86/86 [==============================] - 94s 1s/step - loss: 1.8246 - accuracy: 0.3712 - val_loss: 2.3081 - val_accuracy: 0.2237
# Epoch 3/30
# 86/86 [==============================] - 95s 1s/step - loss: 1.6892 - accuracy: 0.4287 - val_loss: 2.0730 - val_accuracy: 0.3487
# Epoch 4/30
# 86/86 [==============================] - 95s 1s/step - loss: 1.5405 - accuracy: 0.4844 - val_loss: 1.8936 - val_accuracy: 0.4087
# Epoch 5/30
# 86/86 [==============================] - 92s 1s/step - loss: 1.4255 - accuracy: 0.5204 - val_loss: 1.9583 - val_accuracy: 0.4062
# Epoch 6/30
# 86/86 [==============================] - 93s 1s/step - loss: 1.2726 - accuracy: 0.5793 - val_loss: 1.9154 - val_accuracy: 0.4762
# Epoch 7/30
# 86/86 [==============================] - 95s 1s/step - loss: 1.1982 - accuracy: 0.5932 - val_loss: 1.8196 - val_accuracy: 0.4638
# Epoch 8/30
# 86/86 [==============================] - 91s 1s/step - loss: 1.1090 - accuracy: 0.6245 - val_loss: 1.7136 - val_accuracy: 0.4963
# Epoch 9/30
# 86/86 [==============================] - 93s 1s/step - loss: 1.0212 - accuracy: 0.6659 - val_loss: 1.6932 - val_accuracy: 0.5362
# Epoch 10/30
# 86/86 [==============================] - 95s 1s/step - loss: 0.9206 - accuracy: 0.6870 - val_loss: 1.9024 - val_accuracy: 0.5075
# Epoch 11/30
# 86/86 [==============================] - 95s 1s/step - loss: 0.8569 - accuracy: 0.7074 - val_loss: 1.8853 - val_accuracy: 0.5113
# Epoch 12/30
# 86/86 [==============================] - 95s 1s/step - loss: 0.7475 - accuracy: 0.7493 - val_loss: 1.8819 - val_accuracy: 0.5387
# Epoch 13/30
# 86/86 [==============================] - 92s 1s/step - loss: 0.7872 - accuracy: 0.7362 - val_loss: 1.7685 - val_accuracy: 0.5562
# Epoch 14/30
# 86/86 [==============================] - 94s 1s/step - loss: 0.6477 - accuracy: 0.7737 - val_loss: 1.9138 - val_accuracy: 0.5625
# Epoch 15/30
# 86/86 [==============================] - 92s 1s/step - loss: 0.5881 - accuracy: 0.8111 - val_loss: 1.9754 - val_accuracy: 0.5788
# Epoch 16/30
# 86/86 [==============================] - 92s 1s/step - loss: 0.5557 - accuracy: 0.8053 - val_loss: 2.2725 - val_accuracy: 0.5500
# Epoch 17/30
# 86/86 [==============================] - 93s 1s/step - loss: 0.4783 - accuracy: 0.8370 - val_loss: 2.1934 - val_accuracy: 0.5713
# Epoch 18/30
# 86/86 [==============================] - 92s 1s/step - loss: 0.4265 - accuracy: 0.8643 - val_loss: 2.5067 - val_accuracy: 0.5487
# Epoch 19/30
# 86/86 [==============================] - 94s 1s/step - loss: 0.4242 - accuracy: 0.8548 - val_loss: 2.4367 - val_accuracy: 0.6037
# Epoch 20/30
# 86/86 [==============================] - 95s 1s/step - loss: 0.3519 - accuracy: 0.8850 - val_loss: 2.6795 - val_accuracy: 0.5888
# Epoch 21/30
# 86/86 [==============================] - 93s 1s/step - loss: 0.3246 - accuracy: 0.8923 - val_loss: 2.8889 - val_accuracy: 0.5562
# Epoch 22/30
# 86/86 [==============================] - 94s 1s/step - loss: 0.3084 - accuracy: 0.8992 - val_loss: 2.3040 - val_accuracy: 0.6025
# Epoch 23/30
# 86/86 [==============================] - 93s 1s/step - loss: 0.2519 - accuracy: 0.9192 - val_loss: 2.6058 - val_accuracy: 0.5813
# Epoch 24/30
# 86/86 [==============================] - 93s 1s/step - loss: 0.2717 - accuracy: 0.9130 - val_loss: 2.6006 - val_accuracy: 0.5725
# Epoch 25/30
# 86/86 [==============================] - 94s 1s/step - loss: 0.2487 - accuracy: 0.9156 - val_loss: 2.9873 - val_accuracy: 0.5575
# Epoch 26/30
# 86/86 [==============================] - 92s 1s/step - loss: 0.2413 - accuracy: 0.9170 - val_loss: 2.7238 - val_accuracy: 0.5550
# Epoch 27/30
# 86/86 [==============================] - 93s 1s/step - loss: 0.1894 - accuracy: 0.9360 - val_loss: 3.0831 - val_accuracy: 0.5838
# Epoch 28/30
# 86/86 [==============================] - 91s 1s/step - loss: 0.2293 - accuracy: 0.9309 - val_loss: 3.1372 - val_accuracy: 0.5512
# Epoch 29/30
# 86/86 [==============================] - 105s 1s/step - loss: 0.1789 - accuracy: 0.9400 - val_loss: 3.2400 - val_accuracy: 0.5900
# Epoch 30/30
# 86/86 [==============================] - 104s 1s/step - loss: 0.1851 - accuracy: 0.9323 - val_loss: 3.1122 - val_accuracy: 0.5975

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.09598080068826675
# Train Accuracy 0.9687045216560364

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
import matplotlib.pyplot as plt
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot( epochs, accuracy, 'r', label = 'Training accuracy')
plt.plot( epochs, loss, 'b', label = 'Training loss')
plt.show()

# %%
# Lưu 
from google.colab import drive
model.save('10Food.h5')

# %%
# Load model vừa lưu
from tensorflow.keras.models import load_model
model_1=load_model('/content/drive/MyDrive/Recognition_Food/10Food.h5')

# %%
# Chạy thử kết quả
test="/content/drive/MyDrive/Recognition_Food/test"

for i in listdir(test):
  img=load_img(test+'/'+i,target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=(model_1.predict(img).argmax())
  class_name=['Banh beo','Banh chung','Banh mi','Banh pia','Banh xeo','canh chua','Ca kho to','Canh chua','Com tam','Pho', 'Xoi xeo']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Banh beo
# 1/1 [==============================] - 0s 35ms/step
# Pho
# 1/1 [==============================] - 0s 27ms/step
# Canh chua
# 1/1 [==============================] - 0s 22ms/step
# Com tam
# 1/1 [==============================] - 0s 24ms/step
# Banh mi
# 1/1 [==============================] - 0s 27ms/step
# Banh xeo
# 1/1 [==============================] - 0s 23ms/step
# Ca kho to
# 1/1 [==============================] - 0s 25ms/step
# Banh chung
# 1/1 [==============================] - 0s 29ms/step
# Banh mi
# 1/1 [==============================] - 0s 22ms/step
# Banh xeo
